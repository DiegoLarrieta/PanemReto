# %%
import glob
import pandas as pd

# %%
### Load the dataset:
df = pd.read_csv('Complete Data/Carreta/detail_Panem-Carreta_2022-02-18_2022-05-07.csv')




pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

### Display the first 5 rows of the dataset:
df.head()
# Out:
#           sucursal operating_date day_name                closing_time  \
# 0  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:21:04.887000
# 1  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:21:04.887000
# 2  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:21:04.887000
# 3  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:24:44.153000
# 4  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:24:44.153000
#
#                 captured_time  week_number  pdv_txn_id  order_id   order_type  \
# 0  2022-02-18 08:17:48.077000            7           1         1  Para llevar
# 1  2022-02-18 08:17:52.763000            7           1         1  Para llevar
# 2  2022-02-18 08:17:53.950000            7           1         1  Para llevar
# 3  2022-02-18 08:22:25.670000            7           2         2  Para llevar
# 4  2022-02-18 08:22:30.090000            7           2         2  Para llevar
#
#   order_subtype  table_number  party_size           server terminal  \
# 0            '-           NaN           1  Pruebas Carreta  SERVER1
# 1            '-           NaN           1  Pruebas Carreta  SERVER1
# 2            '-           NaN           1  Pruebas Carreta  SERVER1
# 3            '-           NaN           1  Pruebas Carreta  SERVER1
# 4            '-           NaN           1  Pruebas Carreta  SERVER1
#
#   capture_terminal action                       item      modifier group_type  \
# 0          SERVER1  Venta  CHILAQUILES PANEM GRANDES           NaN  Alimentos
# 1          SERVER1  Venta  CHILAQUILES PANEM GRANDES    SALSA ROJA  Alimentos
# 2          SERVER1  Venta  CHILAQUILES PANEM GRANDES     HUEVO +12  Alimentos
# 3          SERVER1  Venta            CAPPUCCINO 16OZ           NaN  Alimentos
# 4          SERVER1  Venta            CAPPUCCINO 16OZ  LECHE ENTERA  Alimentos
#
#                       group  \
# 0                 DESAYUNOS
# 1             MOD ALIMENTOS
# 2             MOD ALIMENTOS
# 3  CAFE Y BEBIDAS CALIENTES
# 4               MOD BEBIDAS
#
#                                                           description  \
# 0  CHILAQUILES PANEM, SALSA ROJA, HUEVO +12, .,** SIN QUESO YCREMA **
# 1                                                          SALSA ROJA
# 2                                                           HUEVO +12
# 3                                    CAPPUCCINO 16OZ, LECHE ENTERA, .
# 4                                                        LECHE ENTERA
#
#   is_modifier  quantity  unit_price  unit_price_with_mods  cost_actual  \
# 0       False       1.0       189.0                 201.0          0.0
# 1        True       1.0         0.0                   0.0          0.0
# 2        True       1.0        12.0                   0.0          0.0
# 3       False       1.0        89.0                  89.0          0.0
# 4        True       1.0         0.0                   0.0          0.0
#
#    cost_with_mods  cost_ideal  discount  subtotal_ticket  iva_ticket  \
# 0             0.0         0.0       0.0         173.2759     27.7241
# 1             0.0         0.0       0.0         173.2759     27.7241
# 2             0.0         0.0       0.0         173.2759     27.7241
# 3             0.0         0.0       0.0         118.9655     19.0345
# 4             0.0         0.0       0.0         118.9655     19.0345
#
#    ieps_ticket  total_ticket  subtotal_item  iva_item  ieps_item  total_item  \
# 0          0.0         201.0       173.2759   27.7241        0.0       201.0
# 1          0.0         201.0         0.0000    0.0000        0.0         0.0
# 2          0.0         201.0        10.3448    1.6552        0.0        12.0
# 3          0.0         138.0        76.7241   12.2759        0.0        89.0
# 4          0.0         138.0         0.0000    0.0000        0.0         0.0
#
#    subtotal_cortesia_cancel  iva_cortesia_cancel  ieps_cortesia_cancel  \
# 0                       NaN                  NaN                   NaN
# 1                       NaN                  NaN                   NaN
# 2                       NaN                  NaN                   NaN
# 3                       NaN                  NaN                   NaN
# 4                       NaN                  NaN                   NaN
#
#    total_cortesia_cancel  subtotal_anulacion  iva_anulacion  ieps_anulacion  \
# 0                    NaN                 NaN            NaN             NaN
# 1                    NaN                 NaN            NaN             NaN
# 2                    NaN                 NaN            NaN             NaN
# 3                    NaN                 NaN            NaN             NaN
# 4                    NaN                 NaN            NaN             NaN
#
#    total_anulacion clave_platillo
# 0              NaN          DE005
# 1              NaN          MA001
# 2              NaN          MA003
# 3              NaN         CBC003
# 4              NaN          MB005

# %%
df.shape
# Out:
# (21524, 46)

# %%
import pandas as pd

### Load the dataset:
df = pd.read_csv('Complete Data/Carreta/detail_Panem-Carreta_2022-02-18_2022-05-07.csv')

### Display the first 5 rows of the dataset:
df.head()
# Out:
#           sucursal operating_date day_name                closing_time  \
# 0  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:21:04.887000
# 1  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:21:04.887000
# 2  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:21:04.887000
# 3  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:24:44.153000
# 4  Panem - Carreta     2022-02-18  viernes  2022-02-18 08:24:44.153000
#
#                 captured_time  week_number  pdv_txn_id  order_id   order_type  \
# 0  2022-02-18 08:17:48.077000            7           1         1  Para llevar
# 1  2022-02-18 08:17:52.763000            7           1         1  Para llevar
# 2  2022-02-18 08:17:53.950000            7           1         1  Para llevar
# 3  2022-02-18 08:22:25.670000            7           2         2  Para llevar
# 4  2022-02-18 08:22:30.090000            7           2         2  Para llevar
#
#   order_subtype  table_number  party_size           server terminal  \
# 0            '-           NaN           1  Pruebas Carreta  SERVER1
# 1            '-           NaN           1  Pruebas Carreta  SERVER1
# 2            '-           NaN           1  Pruebas Carreta  SERVER1
# 3            '-           NaN           1  Pruebas Carreta  SERVER1
# 4            '-           NaN           1  Pruebas Carreta  SERVER1
#
#   capture_terminal action                       item      modifier group_type  \
# 0          SERVER1  Venta  CHILAQUILES PANEM GRANDES           NaN  Alimentos
# 1          SERVER1  Venta  CHILAQUILES PANEM GRANDES    SALSA ROJA  Alimentos
# 2          SERVER1  Venta  CHILAQUILES PANEM GRANDES     HUEVO +12  Alimentos
# 3          SERVER1  Venta            CAPPUCCINO 16OZ           NaN  Alimentos
# 4          SERVER1  Venta            CAPPUCCINO 16OZ  LECHE ENTERA  Alimentos
#
#                       group  \
# 0                 DESAYUNOS
# 1             MOD ALIMENTOS
# 2             MOD ALIMENTOS
# 3  CAFE Y BEBIDAS CALIENTES
# 4               MOD BEBIDAS
#
#                                                           description  \
# 0  CHILAQUILES PANEM, SALSA ROJA, HUEVO +12, .,** SIN QUESO YCREMA **
# 1                                                          SALSA ROJA
# 2                                                           HUEVO +12
# 3                                    CAPPUCCINO 16OZ, LECHE ENTERA, .
# 4                                                        LECHE ENTERA
#
#   is_modifier  quantity  unit_price  unit_price_with_mods  cost_actual  \
# 0       False       1.0       189.0                 201.0          0.0
# 1        True       1.0         0.0                   0.0          0.0
# 2        True       1.0        12.0                   0.0          0.0
# 3       False       1.0        89.0                  89.0          0.0
# 4        True       1.0         0.0                   0.0          0.0
#
#    cost_with_mods  cost_ideal  discount  subtotal_ticket  iva_ticket  \
# 0             0.0         0.0       0.0         173.2759     27.7241
# 1             0.0         0.0       0.0         173.2759     27.7241
# 2             0.0         0.0       0.0         173.2759     27.7241
# 3             0.0         0.0       0.0         118.9655     19.0345
# 4             0.0         0.0       0.0         118.9655     19.0345
#
#    ieps_ticket  total_ticket  subtotal_item  iva_item  ieps_item  total_item  \
# 0          0.0         201.0       173.2759   27.7241        0.0       201.0
# 1          0.0         201.0         0.0000    0.0000        0.0         0.0
# 2          0.0         201.0        10.3448    1.6552        0.0        12.0
# 3          0.0         138.0        76.7241   12.2759        0.0        89.0
# 4          0.0         138.0         0.0000    0.0000        0.0         0.0
#
#    subtotal_cortesia_cancel  iva_cortesia_cancel  ieps_cortesia_cancel  \
# 0                       NaN                  NaN                   NaN
# 1                       NaN                  NaN                   NaN
# 2                       NaN                  NaN                   NaN
# 3                       NaN                  NaN                   NaN
# 4                       NaN                  NaN                   NaN
#
#    total_cortesia_cancel  subtotal_anulacion  iva_anulacion  ieps_anulacion  \
# 0                    NaN                 NaN            NaN             NaN
# 1                    NaN                 NaN            NaN             NaN
# 2                    NaN                 NaN            NaN             NaN
# 3                    NaN                 NaN            NaN             NaN
# 4                    NaN                 NaN            NaN             NaN
#
#    total_anulacion clave_platillo
# 0              NaN          DE005
# 1              NaN          MA001
# 2              NaN          MA003
# 3              NaN         CBC003
# 4              NaN          MB005

# %%
# Out:
# Total files: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       1 all_files = glob.glob(DATA_DIR + "detail_*.csv")
#       2 print(f"Total files: {len(all_files)}")
# ----> 4 df_complete = pd.concat(
#       5     [pd.read_csv(f) for f in all_files],
#       6     ignore_index=True
#       7 )
#       9 print(f"Total rows: {len(df_complete):,}")
#      10 print("\nRows per Branch:")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/reshape/concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/reshape/concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate
