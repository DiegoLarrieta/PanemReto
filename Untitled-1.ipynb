# %%
import pandas as pd
df1 = pd.read_csv("/Users/mak/Desktop/Python challenge/complete data with weather.csv")
df1.shape
# Out:
# (3764683, 47)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", 2000)
pd.set_option("display.max_colwidth", None)

# %%
columnas_datetime = ["operating_date", "closing_time", "captured_time"]
for column in columnas_datetime:
    if column in df1.columns:
        df1[column] = pd.to_datetime(df1[column], errors='coerce')

# %%
h = df1["captured_time"].dt.hour

# You can adjust ranges if needed:
# morning = 06:00-11:59
# between = 12:00-18:59
# night = 19:00-05:59
df1["day_part"] = np.select(
    [
        h.between(6, 11, inclusive="both"),
        h.between(12, 18, inclusive="both")
    ],
    [
        "morning",
        "afternoon"
    ],
    default="night")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 h = df_complete_weather["captured_time"].dt.hour
#       3 # You can adjust ranges if needed:
#       4 # morning = 06:00-11:59
#       5 # between = 12:00-18:59
#       6 # night = 19:00-05:59
#       7 df_complete_weather["day_part"] = np.select(
#       8     [
#       9         h.between(6, 11, inclusive="both"),
#    (...)     15     ],
#      16     default="night")
#
# NameError: name 'df_complete_weather' is not defined
